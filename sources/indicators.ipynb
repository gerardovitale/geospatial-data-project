# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # Global Entrepreneurship Index Ranking (GEI)
# #### The GEI is an economic activity index compiled by US-based The Global Entrepreneurship and Development Institute, which looks at how individual countries across the world allocate resources to promoting entrepreneurship, if indeed they do. The Institute was founded by economic scholars from the Imperial College London, the LSE and the University of Pécs (Hungary) to produce the GEI, which gives a rating of an individual country's entrepreneurship ecosystem. (Wikipedia, 2020)

# %%
df_gei = pd.read_csv('../data/global-entrepreneurship-index.csv',
                    index_col=[0])

# %%
df_gei.head()
# Out:
#    rank         country    GDP   GEI
# 0     1   United States  52676  83.6
# 1     2     Switzerland  54933  80.4
# 2     3          Canada  42104  79.2
# 3     4  United Kingdom  37451  77.8
# 4     5       Australia  42149  75.5

# %%
plt.style.use('seaborn')
fig = plt.figure(figsize=(12,8)) # Create matplotlib figure

ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.

width = 0.35


df_gei.plot.bar(x='country', y='GEI', color='red',
                ax=ax, width=width, position=1, rot=65)
df_gei.plot.bar(x='country', y='GDP', color='blue',
                ax=ax2, width=width, position=0)
ax2.grid(None)
ax.legend(bbox_to_anchor=(0.993,1))
ax2.legend(bbox_to_anchor=(1,0.95))
plt.xlim(-.6)
ax.set_title('Global Entrepreneurship Index (GEI)')
ax.set_xlabel('Country')
ax.set_ylabel('GEI')
ax2.set_ylabel('GDP')
plt.xticks(rotation=55)
fig.tight_layout()
fig.subplots_adjust(top=0.95)
plt.savefig('../outputs/gei-and-gdp-per-country.png')

plt.show()
